# %% [markdown]
# <img src="imgs\banner_fcd.jpg" alt="bannersp" width="1100"  height="150">

# %% [markdown]
# ## <span style="color:#2F749F;"><strong>📦 Sesión práctica 2: Análisis Univariado, bivariado y multivariado</strong></span>
# ---
# <p align="right">
#   <a href="https://colab.research.google.com/#create=true" target="_blank">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Abrir en Colab"/>
#   </a>
# </p>

# %% [markdown]
# ## <span style="color:black;"><strong>Datos del estudiante</strong></span>

# %%
nombre = input("📝 Ingresa tu nombre completo: ")
correo = input("📧 Ingresa tu correo electrónico: ")
cedula = input("🔢 Ingresa los últimos 6 dígitos de tu cédula: ")
# Out:
# 📝 Ingresa tu nombre completo: Karen Cardona Gutierrez
# 📧 Ingresa tu correo electrónico: karen.cardonag@udea.edu.co
# 🔢 Ingresa los últimos 6 dígitos de tu cédula: 686768

# %% [markdown]
# ## <span style="color:black;"><strong>Parte 1: Análisis Univariado</strong></span>

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 1: Cálculo de medidas de tendencia central</strong></span>
#
# A partir de una muestra simulada de ingresos, calcula la **media, mediana y moda**, y luego a interpretarlas.
#
# 1. Usa el número base `528310` (debes reemplazarlo con los últimos 6 dígitos de tu documento de identificación).
# 2. Con este número genera una semilla (`np.random.seed`) para que los resultados sean reproducibles.
# 3. Los ingresos se simulan con una distribución normal:
#    - Media teórica: `(base % 10) + 2`
#    - Desviación estándar: `2`
#    - Tamaño de muestra: `30`
# 4. Los valores negativos se reemplazan por cero (pues los ingresos no pueden ser negativos).
# 5. Grafica tus resultados (ver imagen de ejemplo)
#
# <p align="center">
#     <img src="imgs\sp_2_e1.png" alt="sp_2_e1" width="900"  height="400">
# </p>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

#
numero_base = 686768
np.random.seed(numero_base)
media_teorica = (numero_base % 10) + 2
desviacion_estandar = 2
tamaño_muestra = 100

ingresos = np.random.normal(loc=media_teorica, scale=desviacion_estandar, size=tamaño_muestra).round(1)
ingresos = np.where(ingresos < 0, 0, ingresos)

media = np.mean(ingresos)
mediana = np.median(ingresos)
moda = stats.mode(ingresos, keepdims=True)[0][0]

print ("Medidas de tendencia central")
print(f"Media: {media:.2f} ingresos")
print(f"Mediana: {mediana:.2f} ingresos")
print(f"Moda: {moda:.1f} ingresos")

plt.hist(ingresos, bins=10, edgecolor='black', color='skyblue')
plt.xlabel('Ingresos')
plt.ylabel('Frecuencia')
plt.title('Distribución de Ingresos')
sns.histplot(ingresos, bins=10, kde=True, color='lightblue')
plt.axvline(media, color='red', linestyle="--", linewidth=2, label=f'Media: {media:.2f}')
plt.axvline(mediana, color='green', linestyle="-", linewidth=2, label=f'Mediana: {mediana:.2f}')
plt.axvline(moda, color='purple', linestyle=":", linewidth=2, label=f'Moda: {moda:.2f}')
plt.legend()

plt.show()
# Out:
# Medidas de tendencia central
# Media: 10.10 ingresos
# Mediana: 10.20 ingresos
# Moda: 11.2 ingresos

# %%
ingresos
# Out:
# array([10.2, 11.9,  8.2, 11.8,  8. , 10.4, 11.2, 10.3,  8.7,  9.7, 10.5,
#        12.4,  9.2,  9.4,  9.4, 10.9, 11.6,  9.3,  7.5,  5.5, 10.7,  9. ,
#         5.6, 12.5, 11.2, 11.4,  9. , 10.7, 11.2,  7.5,  9.1, 11.2, 11.9,
#        12.5,  8.4, 11.9, 11. , 12.4,  6.9, 11.9, 12.4, 11.2,  6.6, 10.3,
#        12.3, 10.7, 10.1, 11.6, 12.6, 10.1, 11.8,  9.2, 10.2,  9.9,  9.2,
#        13.1, 11.3,  8.2, 14.2,  8.7,  9.9,  9.1, 12.2,  9.8,  8.7, 11.2,
#        10.1,  9.2,  6. , 10.3, 10.8, 10.6, 14. ,  9.5, 10. ,  9.6, 10.3,
#        10.8, 12.6,  7. ,  8.8, 10.2, 12.1,  9.7,  9.6,  7.6, 11.8, 11. ,
#         8.1,  5.8,  5.5, 11.2,  9.5, 10.1, 11.6,  5. , 10.2, 15.8, 10.6,
#         8.5])

# %% [markdown]
# **Media:** En promedio los ingresos se ubican alrededor de 10.10
#
# **Mediana:** El ingreso que se encuentra en la mitad de los datos es de 10.2
#
# **Moda:** El valor de ingresos más observado es de 11.2

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 2: Cálculo de medidas de dispersión</strong></span>
#
# A partir de la muestra generada en el Ejercicio 1, analiza qué tan dispersos están los datos respecto a su media. Calcula:
# 1. Rango
# 2. Varianza
# 3. Desviación estándar
# 4. Coeficiente de variación
# 5. Genera una gráfica con los resultados obtenidos (ver imagen de ejemplo)
#
# <p align="center">
#     <img src="imgs\sp_2_e2.png" alt="sp_2_e2" width="900"  height="400">
# </p>

# %%
# Cálculo de medidas de dispersión
media = np.mean(ingresos)
minimo = np.min(ingresos)
maximo = np.max(ingresos)
rango = maximo - minimo
varianza = np.var(ingresos, ddof=1)
desviacion = np.std(ingresos, ddof=1)
coef_var = desviacion / media


plt.hist(ingresos, bins=10, edgecolor='black',color='skyblue')
plt.xlabel('Ingresos')
plt.ylabel('Frecuencia')
plt.title('Distribución de Ingresos')
sns.histplot(ingresos, bins=10, kde=True, color='lightblue')
plt.axvline(media, color='green', linestyle='--', linewidth=2, label=f'Media = {media:.2f}')
plt.axvline(media + desviacion, color='orange', linestyle=':', linewidth=1.5, label=f'+1σ = {media + desviacion:.2f}')
plt.axvline(media - desviacion, color='orange', linestyle=':', linewidth=1.5, label=f'-1σ = {media - desviacion:.2f}')
plt.axvline(minimo, color='red', linestyle='-', linewidth=1.5, label=f'Mínimo = {minimo}')
plt.axvline(maximo, color='red', linestyle='-', linewidth=1.5, label=f'Máximo = {maximo}')
plt.legend()
texto = (
    f"Rango: {rango}\n"
    f"Varianza: {varianza:.2f}\n"
    f"Desviación estándar: {desviacion:.2f}\n"
    f"Coef. de variación: {coef_var:.2f}"
)
plt.text(18, 10, texto, bbox=dict(facecolor='lightgreen', alpha=0.3), fontsize=10)


plt.show()

# %% [markdown]
# Los ingresos presentan una dispersión moderada. La mayoría de los valores se concentran cerca de la media (10.10), dentro de un rango de 2 unidades aproximadamente. El coeficiente de variación del 20% indica que no hay una gran variabilidad, por lo que los ingresos son bastante estables, aunque existen casos extremos entre 5 y 15.8.

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 3: Cálculo de medidas de distribución</strong></span>
#
# A partir de la muestra generada en el Ejercicio 1, analiza la distribución de los datos. Calcula:
# 1. Asimetría
# 2. Curtosis
# 3. Realiza la comparación con la distribución normal (ver la imagen de ejemplo)
#
# <p align="center">
#     <img src="imgs\sp_2_e3.png" alt="sp_2_e3" width="900"  height="400">
# </p>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis
import pandas as pd


sns.set_theme(style="whitegrid")

numero_base = 686768
np.random.seed(numero_base)

df = pd.DataFrame({'Ingresos': ingresos})

asimetria = skew(ingresos)
curtosis_valor = kurtosis(ingresos)

print(f"Asimetría: {asimetria:.2f}")
print(f"Curtosis: {curtosis_valor:.2f}")
# Out:
# Asimetría: -0.34
# Curtosis: 0.48

# %%
# Visualización
plt.figure(figsize=(10, 6))
sns.histplot(df['Ingresos'], kde=True, color='skyblue', bins=10)
plt.axvline(df['Ingresos'].mean(), color='red', linestyle='--', label=f'Media= {media:.2f}')

plt.text(0.05, 0.95, f"Asimetría: {asimetria:.2f}", transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.6))
plt.text(0.05, 0.88, f"Curtosis: {curtosis_valor:.2f}", transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.6))

plt.title('Distribución de la muestra vs. distribución normal ')
plt.xlabel('número Ingresos')
plt.ylabel('Frecuencia')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 4: Cálculo de medidas de percentiles</strong></span>
#
# A partir de la muestra generada en el Ejercicio 1, calcula los percentiles de tus datos. Calcula:
# 1. Percentiles
# 2. Deciles
# 3. Cuartiles
# 4. Grafica los anteriores percentiles calculados, sobre la distribución de tus datos (ver la imagen de ejemplo)
#
# <p align="center">
#     <img src="imgs\sp_2_e4.png" alt="sp_2_e4" width="900"  height="400">
# </p>

# %%
sns.set_theme(style="whitegrid")

percentiles = {
    'P10': {'valor': np.percentile(ingresos, 10), 'color': 'red', 'linestyle': '-'},
    'P25 (Q1)': {'valor': np.percentile(ingresos, 25), 'color': 'orange', 'linestyle': '--'},
    'P50 (Mediana)': {'valor': np.percentile(ingresos, 50), 'color': 'green', 'linestyle': '-.'},
    'P75 (Q3)': {'valor': np.percentile(ingresos, 75), 'color': 'blue', 'linestyle': ':'},
    'P90': {'valor': np.percentile(ingresos, 90), 'color': 'purple', 'linestyle': (0, (5, 2))}
}

deciles = {f'D{i}': np.percentile(ingresos, i * 10) for i in range(1, 10)}

cuartiles = {f'Q{i}': np.percentile(ingresos, i * 25) for i in range(1, 4)}

plt.figure(figsize=(14, 7))
sns.histplot(ingresos, kde=True, color='skyblue', bins=10)

for etiqueta, props in percentiles.items():
    plt.axvline(props['valor'], color=props['color'], linestyle='-',
                linewidth=2)
    plt.text(props['valor'], plt.ylim()[1]*0.9, etiqueta,
             rotation=90, color=props['color'], fontsize=10,
             verticalalignment='center', horizontalalignment='right',
             backgroundcolor='white')

for etiqueta, valor in deciles.items():
    plt.axvline(valor, color='gray', linestyle='--', alpha=0.3)
    plt.text(valor, plt.ylim()[1]*0.6, etiqueta,
             rotation=90, color='gray', fontsize=8,
             verticalalignment='center', horizontalalignment='right')


for etiqueta, valor in cuartiles.items():
    plt.axvline(valor, color='black', linestyle=':', alpha=0.3)
    plt.text(valor, plt.ylim()[1]*0.7, etiqueta,
             rotation=90, color='black', fontsize=9,
             verticalalignment='center', horizontalalignment='right')

plt.title("Distribución Normal con Percentiles, Deciles y Cuartiles", fontsize=14, fontweight='bold')
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## <span style="color:black;"><strong>Parte 2: Análisis Bivariado</strong></span>

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 5: Análisis de correlación</strong></span>
#
# En esta segunda parte, genera **dos variables** a partir de tú número de cédula y realiza un análisis **bivariado** para calcular la relación entre ellas.
#
# 1. Use los **6 últimos dígitos** de su cédula como base (similar al Ejercicio 1).
# 2. Genere dos variables aleatorias (ejemplo: `ingresos` y `gastos`) con distribución normal, usando esa base como **semilla reproducible**.
# 3. Calcule los coeficientes de correlación de **Pearson** y **Spearman**.
# 4. Grafique las variables analizadas (ver la imagen de ejemplo)
# 5. Interprete los resultados.
#
# <p align="center">
#     <img src="imgs\sp_2_e5.png" alt="sp_2_e5" width="900"  height="400">
# </p>

# %%
np.random.seed(686768)
media_teorica = (numero_base % 10) + 2
desviacion_estandar = 2
tamaño_muestra = 100


ingresos = np.random.normal(loc=media_teorica, scale=desviacion_estandar, size=tamaño_muestra).round(1)
ingresos = np.where(ingresos < 0, 0, ingresos)
gastos = np.random.normal(loc=media_teorica, scale=desviacion_estandar, size=tamaño_muestra).round(1)
gastos = np.where(gastos < 0, 0, gastos)

r1,_ = stats.pearsonr(ingresos, gastos)
r2,_ = stats.spearmanr(ingresos, gastos)

sns.set_theme(style="whitegrid")

plt.figure(figsize=(10, 5))
sns.scatterplot(x=ingresos, y=gastos, color='skyblue', alpha=0.7)
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.axvline(0, color='black', linestyle='--', linewidth=1)
plt.title("Pearson vs Spearman", fontsize=14, fontweight='bold')
plt.text(0.05, 0.95, f"Coef. Pearson:{r1:.2f}", transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.6))
plt.text(0.05, 0.88, f"Coef. Spearman:{r2:.2f}", transform=plt.gca().transAxes,
         fontsize=12,verticalalignment='top', bbox=dict(facecolor='white', alpha=0.6))
plt.xlabel("Ingresos")
plt.ylabel("Gastos")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretación:**
# Los resultados muestran un coeficiente de Pearson de 0.03 y un coeficiente de Spearman de -0.03, lo que indica ausencia de correlación lineal y ausencia de correlación monótona entre las variables analizadas. En conclusión, los ingresos y los gastos en esta muestra no presentan relación significativa.

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>Ejercicio 6: Chi-Cuadrado</strong></span>
#
# En esta parte, analiza si existe **asociación estadística** entre dos variables categóricas simuladas a partir de tu número de cédula.
#
# 1. Usa los **6 últimos dígitos** de tu cédula como base para generar una semilla reproducible.
# 2. Simula una muestra de **60 personas** con dos variables categóricas:
#    - `Nivel educativo`: Básico, Medio, Superior.
#    - `Acceso a internet`: Sí, No.
# 3. Crea una **tabla de contingencia** entre ambas variables.
# 4. Aplica la **prueba de Chi cuadrado de independencia**.
# 5. Visualiza la distribución conjunta con un mapa de calor (ver la imagen de con la información de ejemplo).
# 6. Interpreta el resultado.
#
# <p align="center">
#     <img src="imgs\sp_2_e6.png" alt="sp_2_e6" width="900"  height="700">
# </p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

np.random.seed(686768)

n = 60
niveles = ["Básico", "Medio", "Superior"]
internet = ["Sí", "No"]
nivel_educativo = np.random.choice(niveles, size=n, )
acceso_internet = np.random.choice(internet, size=n,)
df = pd.DataFrame({
    "Nivel_Educativo": nivel_educativo,
    "Acceso_Internet": acceso_internet
})

tabla = pd.crosstab(df["Nivel_Educativo"], df["Acceso_Internet"])
print("Tabla de contingencia:\n", tabla)

chi2, p, dof, esperados = chi2_contingency(tabla)
print(f"\nChi2 = {chi2:.3f}, p-valor = {p:.3f}, grados de libertad = {dof}")
print("Valores esperados:\n", esperados)

plt.figure(figsize=(6,4))
sns.heatmap(tabla, annot=True, fmt="d", cmap="Blues")
plt.title("Mapa de calor: Nivel educativo vs Acceso a internet")
plt.show()
# Out:
# Tabla de contingencia:
#  Acceso_Internet  No  Sí
# Nivel_Educativo
# Básico           12   5
# Medio            12   7
# Superior         14  10
#
# Chi2 = 0.644, p-valor = 0.725, grados de libertad = 2
# Valores esperados:
#  [[10.76666667  6.23333333]
#  [12.03333333  6.96666667]
#  [15.2         8.8       ]]

# %% [markdown]
# **Interpretación:**
# La prueba de Chi-cuadrado arrojó un estadístico de x² = 0.644 con un p-valor = 0.725 y 2 grados de libertad. Dado que el p-valor es mayor que 0.05, no hay evidencia suficiente para afirmar que las variables están relacionadas.
#
# Esto indica que en la muestra analizada no existe una asociación estadísticamente significativa entre el nivel educativo y el acceso a internet. Los valores observados en la tabla de contingencia son muy cercanos a los valores esperados bajo independencia, lo cual refuerza esta conclusión.
#
# En otras palabras, el acceso a internet parece distribuirse de manera similar en los diferentes niveles educativos, sin diferencias relevantes entre ellos.
